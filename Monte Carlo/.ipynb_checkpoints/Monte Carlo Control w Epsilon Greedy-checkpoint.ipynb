# %%
# %matplotlib inline

import gym
import matplotlib
import numpy as np
import sys

from collections import defaultdict
if "../" not in sys.path:
    sys.path.append("../") 
from lib.envs.blackjack import BlackjackEnv
from lib import plotting

matplotlib.style.use('ggplot')

# %%
env = BlackjackEnv()

# %%
def make_epsilon_greedy_policy(Q, epsilon, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function and epsilon.
    
    Args:
        Q: A dictionary that maps from state -> action-values.
            Each value is a numpy array of length nA (see below)
        epsilon: The probability to select a random action . float between 0 and 1.
        nA: Number of actions in the environment.
    
    Returns:
        A function that takes the observation as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.
    
    """
    def policy_fn(observation):
        A = np.ones(nA, dtype=float)*epsilon / nA
        best_action = np.argmax(Q[tuple(observation)])
        A[best_action] += 1-epsilon
        return A
        # Implement this!
    return policy_fn

# %%
def mc_control_epsilon_greedy(env, num_episodes, discount_factor=1.0, epsilon=0.1):
    """
    Monte Carlo Control using Epsilon-Greedy policies.
    Finds an optimal epsilon-greedy policy.
    
    Args:
        env: OpenAI gym environment.
        num_episodes: Number of episodes to sample.
        discount_factor: Gamma discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.
    
    Returns:
        A tuple (Q, policy).
        Q is a dictionary mapping state -> action values.
        policy is a function that takes an observation as an argument and returns
        action probabilities
    """
    
    # Keeps track of sum and count of returns for each state
    # to calculate an average. We could use an array to save all
    # returns (like in the book) but that's memory inefficient.
    returns_sum = defaultdict(float)
    returns_count = defaultdict(float)
    
    # The final action-value function.
    # A nested dictionary that maps state -> (action -> action-value).
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
        
    # The policy we're following
    policy = make_epsilon_greedy_policy(Q, epsilon, env.action_space.n)
    
    for i_episode in range(num_episodes):
        state = env.reset()
        episode = []
        done = False
        while not done:
            action_probs = policy(state)
            action = np.random.choice(np.arange(len(action_probs)),p=action_probs)
            next_state, reward, done, _ = env.step(action)
            episode.append((state, action, reward))
            state = next_state
        
        state_action_pairs = set([tuple([tuple(x[0]),x[1]]) for x in episode])
        for s_a in state_action_pairs:
            first_idx = next(i for i,x in enumerate(episode) if tuple([x[0],x[1]])==s_a)
            G = sum([x[2]*(discount_factor**i) for i,x in enumerate(episode[first_idx:])])
            returns_sum[s_a] += G
            returns_count[s_a] += 1.0
            Q[s_a[0]][s_a[1]] = returns_sum[s_a]/returns_count[s_a]
            
    # Implement this!
    
    return Q, policy

# %%
Q, policy = mc_control_epsilon_greedy(env, num_episodes=2000000, epsilon=0.3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/86/js9dryt54f58qm967v61q7xm0000gp/T/ipykernel_22105/1134901783.py in <module>
# ----> 1 Q, policy = mc_control_epsilon_greedy(env, num_episodes=2000000, epsilon=0.3)
#
# /var/folders/86/js9dryt54f58qm967v61q7xm0000gp/T/ipykernel_22105/2038657442.py in mc_control_epsilon_greedy(env, num_episodes, discount_factor, epsilon)
#      35         done = False
#      36         while not done:
# ---> 37             action_probs = policy(state)
#      38             action = np.random.choice(np.arange(len(action_probs)),p=action_probs)
#      39             next_state, reward, done, _ = env.step(action)
#
# /var/folders/86/js9dryt54f58qm967v61q7xm0000gp/T/ipykernel_22105/3019918387.py in policy_fn(observation)
#      15     """
#      16     def policy_fn(observation):
# ...

# %%
# For plotting: Create value function from action-value function
# by picking the best action at each state
V = defaultdict(float)
for state, actions in Q.items():
    action_value = np.max(actions)
    V[state] = action_value
plotting.plot_value_function(V, title="Optimal Value Function")

# %% [markdown]
# ## Plotting the Optimal Policy

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# x -> player sum | y -> dealer showing
min_x = min([k[0] for k in Q.keys()])
max_x = max([k[0] for k in Q.keys()])
min_y = min([k[1] for k in Q.keys()])
max_y = max([k[1] for k in Q.keys()])

# %%
Q_usable_ace = np.zeros((10,10))
Q_no_usable_ace = np.zeros((10,10))
for state, actions in Q.items():
    if state[-1] == True:
        Q_usable_ace[state[0]-min_x][state[1]-min_y] = np.argmax(actions)
    else:
        Q_no_usable_ace[state[0]-min_x][state[1]-min_y] = np.argmax(actions)

# %%
_, axes = plt.subplots(1,2,figsize=(40,10))
titles = ['Optimal Policy (No Usable Ace)', 'Optimal Policy (Usable Ace)']
images = [Q_no_usable_ace, Q_usable_ace]

for title, image, ax in zip(titles[::-1], images[::-1], axes):
    fig = sns.heatmap(np.flipud(image), cmap="YlGnBu", ax=ax, xticklabels=range(1, 11),
                              yticklabels=list(reversed(range(12, 22))))
    fig.set_ylabel('player sum', fontsize=30)
    fig.set_xlabel('dealer showing', fontsize=30)
    fig.set_title(title, fontsize=30)

# %%
Q[(12,4,False)]
# Out:
# array([-0.22375427, -0.31486239])
